# %%
import numpy as np
import pandas as pd

a = np.array([10, 20, 30, 40, 50])

print("Array:", a)
print("Mean:", a.mean())
print("Reshaped 2D:\n", a.reshape(5, 1))
print("Sliced:", a[1:4])

data = {
    "Name": ["Rahul", "Shreya", "Karan", "priya"],
    "Marks": [88, 72, 91, 65],
    "Branch": ["CSE", "ECE", "CSE", "ISE"]
}

df = pd.DataFrame(data)

print(df)

print("\nFirst 2 rows:\n", df.iloc[0:2])

print("\nMarks column:\n", df["Marks"])

print("\nRows where marks > 70:\n", df[df["Marks"] > 70])
# Out:
# Array: [10 20 30 40 50]
# Mean: 30.0
# Reshaped 2D:
#  [[10]
#  [20]
#  [30]
#  [40]
#  [50]]
# Sliced: [20 30 40]
#      Name  Marks Branch
# 0   Rahul     88    CSE
# 1  Shreya     72    ECE
# 2   Karan     91    CSE
# 3   priya     65    ISE
#
# First 2 rows:
#       Name  Marks Branch
# 0   Rahul     88    CSE
# 1  Shreya     72    ECE
#
# Marks column:
#  0    88
# 1    72
# 2    91
# 3    65
# Name: Marks, dtype: int64
#
# Rows where marks > 70:
#       Name  Marks Branch
# 0   Rahul     88    CSE
# 1  Shreya     72    ECE
# 2   Karan     91    CSE
